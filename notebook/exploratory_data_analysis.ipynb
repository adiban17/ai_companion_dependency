# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Importing the Data

# %%
df = pd.read_csv('/Users/adityabanerjee/Library/CloudStorage/GoogleDrive-adityabanerjee171@gmail.com/My Drive/Projects/AI Companion Dependency/notebook/data/ai_companion_dependency_dataset.csv')

# %% [markdown]
# ### Exploring the Data

# %%
# First 5 rows
df.head(5)
# Out:
#   user_id  age      gender   occupation_status education_level  income_level  \
# 0   U0001   21        Male  Employed Full-Time     High School  Lower-Middle
# 1   U0002   34        Male             Student        Graduate  Upper-Middle
# 2   U0003   43        Male  Employed Full-Time        Graduate           Low
# 3   U0004   29  Non-binary  Employed Full-Time        Graduate           Low
# 4   U0005   25      Female             Student        Graduate  Upper-Middle
#
#   relationship_status living_situation country_region ai_chatbot_platform  \
# 0   In a Relationship     With Partner  South America             ChatGPT
# 1              Single            Alone  North America        Character.AI
# 2              Single            Alone         Europe        Character.AI
# 3              Single      With Family           Asia             ChatGPT
# 4   In a Relationship   With Roommates  South America             ChatGPT
#
# ...

# %%
# Last 5 rows
df.tail()
# Out:
#     user_id  age  gender   occupation_status education_level  income_level  \
# 995   U0996   35  Female             Student   Undergraduate           Low
# 996   U0997   19    Male             Student   Undergraduate  Lower-Middle
# 997   U0998   24    Male  Employed Part-Time     High School  Lower-Middle
# 998   U0999   24    Male  Employed Part-Time     High School  Lower-Middle
# 999   U1000   33    Male  Employed Part-Time   Undergraduate  Lower-Middle
#
#     relationship_status living_situation country_region ai_chatbot_platform  \
# 995   In a Relationship     With Partner           Asia        Character.AI
# 996             Married      With Family  North America              Claude
# 997              Single      With Family  South America        Character.AI
# 998              Single      With Family         Europe             ChatGPT
# 999              Single   With Roommates         Europe             ChatGPT
#
# ...

# %%
# List of features in the data
features = df.columns
features
# Out:
# Index(['user_id', 'age', 'gender', 'occupation_status', 'education_level',
#        'income_level', 'relationship_status', 'living_situation',
#        'country_region', 'ai_chatbot_platform', 'primary_use_case',
#        'daily_ai_chat_hours', 'human_social_interaction_hours',
#        'social_media_hours_daily', 'screen_time_total_hours',
#        'number_of_close_friends', 'loneliness_score',
#        'emotional_attachment_score', 'real_relationship_satisfaction',
#        'prefers_ai_over_humans', 'sleep_hours', 'sleep_quality_score',
#        'exercise_hours_weekly', 'anxiety_score', 'depression_score',
#        'stress_score', 'self_esteem_score',
#        'academic_or_work_performance_change', 'therapy_attendance',
#        'dependency_risk_label'],
#       dtype='str')

# %%
# Number of Features
len(features)
# Out:
# 30

# %%
# Statistical Summary
df.describe()
# Out:
#                age  daily_ai_chat_hours  human_social_interaction_hours  \
# count  1000.000000          1000.000000                      1000.00000
# mean     29.940000             1.613470                         3.98939
# std       9.033493             1.309653                         1.51918
# min      15.000000             0.000000                         0.00000
# 25%      22.000000             0.500000                         2.94750
# 50%      30.000000             1.440000                         3.93500
# 75%      38.000000             2.530000                         5.00250
# max      44.000000             6.520000                         9.75000
#
#        social_media_hours_daily  screen_time_total_hours  \
# count               1000.000000              1000.000000
# mean                   2.508770                 6.093740
# std                    1.369145                 2.625688
# min                    0.000000                 1.000000
# ...

# %%
# Summary
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   user_id                              1000 non-null   str
#  1   age                                  1000 non-null   int64
#  2   gender                               1000 non-null   str
#  3   occupation_status                    1000 non-null   str
#  4   education_level                      1000 non-null   str
#  5   income_level                         1000 non-null   str
#  6   relationship_status                  1000 non-null   str
#  7   living_situation                     1000 non-null   str
#  8   country_region                       1000 non-null   str
#  9   ai_chatbot_platform                  1000 non-null   str
#  10  primary_use_case                     1000 non-null   str
# ...

# %%
# Check for null values
df.isnull().sum()
# Out:
# user_id                                0
# age                                    0
# gender                                 0
# occupation_status                      0
# education_level                        0
# income_level                           0
# relationship_status                    0
# living_situation                       0
# country_region                         0
# ai_chatbot_platform                    0
# primary_use_case                       0
# daily_ai_chat_hours                    0
# human_social_interaction_hours         0
# social_media_hours_daily               0
# screen_time_total_hours                0
# number_of_close_friends                0
# loneliness_score                       0
# emotional_attachment_score             0
# real_relationship_satisfaction         0
# prefers_ai_over_humans                 0
# sleep_hours                            0
# sleep_quality_score                    0
# exercise_hours_weekly                  0
# ...

# %%
# Check for duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Insights:
# - We have a total of 1000 participants data
# - We have a total of 30 features
# - `dependency_risk_label` is our target feature
# - We have 0 duplicate rows
# - We have 0 null values

# %% [markdown]
# ### Exploring features

# %%
for feature in features:
    print(feature)
# Out:
# user_id
# age
# gender
# occupation_status
# education_level
# income_level
# relationship_status
# living_situation
# country_region
# ai_chatbot_platform
# primary_use_case
# daily_ai_chat_hours
# human_social_interaction_hours
# social_media_hours_daily
# screen_time_total_hours
# number_of_close_friends
# loneliness_score
# emotional_attachment_score
# real_relationship_satisfaction
# prefers_ai_over_humans
# sleep_hours
# sleep_quality_score
# exercise_hours_weekly
# anxiety_score
# depression_score
# stress_score
# self_esteem_score
# academic_or_work_performance_change
# therapy_attendance
# dependency_risk_label

# %% [markdown]
# #### Exploring the `user_id` feature

# %% [markdown]
# - The `user_id` feature is used to differentiate between different users.
# - Every unique user has a unique `user_id`

# %%
df['user_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Insights:
# - We can conclude that every user has a unique `user_id`

# %% [markdown]
# #### Exploring the `age` feature

# %% [markdown]
# - The `age` denotes the age of the person in the survey

# %%
# Range
max_age = df['age'].max()
min_age = df['age'].min()
mode_age = df['age'].mode()
print(f"The age varies from {min_age} - {max_age} with the most common age being {mode_age[0]}")
# Out:
# The age varies from 15 - 44 with the most common age being 42

# %%
# Visualizing the age-frequency distribution
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='age', bins=30, kde=False, color='teal')
plt.title('Frequency Distribution by Age')
plt.xlabel('Age of the Participants')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - The maximum age is 44
# - The minimum age is 15
# - The most common age is 42

# %% [markdown]
# #### Exploring the `gender` feature

# %% [markdown]
# - `gender` tells us the gender of the participant

# %%
# Count of unique genders
gender_counts = df['gender'].value_counts()
gender_counts
# Out:
# gender
# Male                 468
# Female               452
# Non-binary            53
# Prefer not to say     27
# Name: count, dtype: int64

# %%
# Visulaizing the composition by gender
plt.figure(figsize=(8, 8))
plt.title('Survey Composition by Gender')
gender_counts.plot(
    kind='pie', 
    autopct='%1.1f%%',       
    startangle=140,         
    colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'], 
    explode=(0.05, 0, 0, 0)  
)
# Out:
# <Axes: title={'center': 'Survey Composition by Gender'}>

# %% [markdown]
# Insights:
# - There are 4 gender categories
# - The highest count is that of `male` closely followed by `female`
# - A very small portion of people `Prefer not to say`

# %% [markdown]
# #### Exploring the `occupation_status` column

# %% [markdown]
# - The `occupation_status` tell us whether the participant is a `Student`, `Unemployed`, `Freelancer`, '`Employed Full-Time` or `Employed Part-Time`

# %%
occupations = df['occupation_status'].value_counts()
occupations
# Out:
# occupation_status
# Student               404
# Employed Full-Time    314
# Employed Part-Time    126
# Unemployed             88
# Freelancer             68
# Name: count, dtype: int64

# %%
# Visualizing the occupation by frequency counts
plt.figure(figsize=(10, 8))
my_colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#C9CBFF']
plt.xlabel('Occupation Status')
plt.ylabel('Counts')
plt.title('Distribution of Participants by Occupation')
plt.bar(x=occupations.index, height=occupations.values, color=my_colors);

# %% [markdown]
# Insights:
# - Most of the participants are students
# - The least number of participants are Freelancers and Unemployed

# %% [markdown]
# #### Exploring the `education_level` feature

# %% [markdown]
# - `education_level` feature tells us the highest level of education that the participant has completed at the time of the survey

# %%
# Unique value count
education_level_counts = df['education_level'].value_counts()
education_level_counts
# Out:
# education_level
# Undergraduate    385
# Graduate         268
# High School      253
# Postgraduate      94
# Name: count, dtype: int64

# %%
# Visulaizing the composition by education_level
plt.figure(figsize=(8, 8))
plt.title('Survey Composition by Education Level')
education_level_counts.plot(
    kind='pie', 
    autopct='%1.1f%%',       
    startangle=140,         
    colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'], 
    explode=(0.05, 0, 0, 0)  
)
# Out:
# <Axes: title={'center': 'Survey Composition by Education Level'}>

# %% [markdown]
# #### Exploring the `income_level` feature

# %% [markdown]
# - The `income_level` gives us an idea about the net income of the individual being surveyed on an annual basis in USD ($).
# - They have been categorized into `Low`, `Lower-Middle`, `Upper-Middle`, `High`

# %%
# Income Level Counts
df['income_level'].value_counts()
# Out:
# income_level
# Lower-Middle    379
# Upper-Middle    259
# Low             259
# High            103
# Name: count, dtype: int64

# %%
# Visulaizing the composition by income level
plt.figure(figsize=(8, 8))
income_level_counts = df['income_level'].value_counts()
plt.title('Survey Composition by Income Level')
income_level_counts.plot(
    kind='pie', 
    autopct='%1.1f%%',       
    startangle=140,         
    colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'], 
    explode=(0.05, 0, 0, 0)  
)
# Out:
# <Axes: title={'center': 'Survey Composition by Income Level'}>

# %% [markdown]
# Insights:
# - The highest compisition is that of Lower-Middle class then followed by Upper-Middle class and Lower Class
# - Th least composition is that of the High Income Individuals

# %% [markdown]
# #### Exploring the `relationship_status` column

# %% [markdown]
# - This column tells us the relationship status of the indivduals in the survey.

# %%
# Value Counts
df['relationship_status'].value_counts()
# Out:
# relationship_status
# Single                469
# In a Relationship     280
# Married               194
# Divorced/Separated     57
# Name: count, dtype: int64

# %%
# Visualizing the relationship_status-frequency distribution
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='relationship_status', bins=4, kde=False, color='pink')
plt.title('Frequency Distribution by Relationship Status')
plt.xlabel('Relationship Status')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - Majority of the participants are Single
# - The least people in the survey are Divorced

# %% [markdown]
# #### Exploring the `living_situation` column

# %% [markdown]
# - This column tells us how the individual taking the survey is living (the people he is living with)

# %%
# Value Counts
ls_counts = df['living_situation'].value_counts()
ls_counts
# Out:
# living_situation
# With Family       396
# Alone             213
# With Roommates    200
# With Partner      191
# Name: count, dtype: int64

# %%
# Visualizing the living_situation by frequency counts
plt.figure(figsize=(8, 6))
my_colors = ['#FF9999', '#66B3FF', '#FFCC99', '#C9CBFF']
plt.xlabel('Living Situation')
plt.ylabel('Counts')
plt.title('Distribution of Participants by Living Situation')
plt.bar(x=ls_counts.index, height=ls_counts.values, color=my_colors);

# %% [markdown]
# Insights:
# - Most of the surveyors live with their family
# - The rest of them who live alone, with roommates, with partner have similar counts

# %% [markdown]
# #### Exploring the `country_region` feature

# %% [markdown]
# - This feature tells us the continent that the surveyor is coming from

# %%
# Value Counts 
region_counts = df['country_region'].value_counts()
region_counts
# Out:
# country_region
# Asia             358
# North America    249
# Europe           187
# South America     96
# Africa            92
# Oceania           18
# Name: count, dtype: int64

# %%
# Visualizing the country_region-frequency distribution
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='country_region', bins=4, kde=False, color='grey')
plt.title('Frequency Distribution by Continent')
plt.xlabel('Continent')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - The most of the surveyors are from Asia
# - The least number of surveyors are from Oceania

# %% [markdown]
# #### Exploring the `ai_chatbot_platform` feature

# %% [markdown]
# - Tells us the preferred chatbot the user uses to talk to

# %%
# Value Counts
platform_counts = df['ai_chatbot_platform'].value_counts()
platform_counts
# Out:
# ai_chatbot_platform
# ChatGPT           396
# Character.AI      254
# Replika           149
# Claude            108
# Other/Multiple     93
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99', '#c2c2f0']
platform_counts.plot(
    kind='pie', 
    autopct='%1.1f%%', 
    colors=colors,
    startangle=90,
    explode=(0.05, 0, 0, 0, 0) 
)
plt.title('AI Chatbot Platform Preference')
plt.ylabel('') 
plt.show()

# %% [markdown]
# Insights:
# - Most of the people prefer speaking to ChatGPT followed by Character.AI

# %% [markdown]
# #### Exploring the `primary_use_case` feature

# %% [markdown]
# - This feature gives us an idea of the primary reasons on why the user uses the AI ChatBot

# %%
# Value Counts
df['primary_use_case'].value_counts()
# Out:
# primary_use_case
# Productivity/Work     309
# Companionship         262
# Entertainment         173
# Therapy-Substitute    149
# Learning              107
# Name: count, dtype: int64

# %%
# Visualization
plt.figure(figsize=(12,6))
plt.title('Primary Use Cases of the ChatBot')
plt.xlabel('User Counts')
plt.ylabel('Use Case')
plt.barh(y=df['primary_use_case'].value_counts().index, width=df['primary_use_case'].value_counts().values, color='skyblue', edgecolor='black', height=0.7)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Insights:
# - Most of the people use AI for Work/Productivity
# - It is closely followed by companionship
# - The people who use AI for companionship are more likely to get dependent

# %% [markdown]
# #### Exploring the `daily_ai_chat_hours` feature

# %% [markdown]
# - This feature tell us how many hours does the user uses the AI chatbot on average on a daily basis.

# %%
# Range
max = df['daily_ai_chat_hours'].max()
min = df['daily_ai_chat_hours'].min()
mode = df['daily_ai_chat_hours'].mode()
print(f"Min:{min}\nMax:{max}\nMode:{mode[0]}")
# Out:
# Min:0.0
# Max:6.52
# Mode:0.0

# %%
# Visualization
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='daily_ai_chat_hours', bins=10, kde=True, color='green')
plt.title('Frequency Distribution by Daily AI Chat Hours')
plt.xlabel('Number of Hours')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - Most of the people chat lesss than an hour each day with AI.
# - With the maximum reaching over 6 hours (outlier)
# - The more someone chats with AI the more prone they are to become dependent on it for companionship

# %% [markdown]
# #### Exploring the `human_social_interaction_hours` feature

# %% [markdown]
# - This feature tell us how many hours per day does the surveyor engages in a social interaction.
# - The social interaction can be with a friend, a family member, a colleague or with a partner.

# %%
# Range
max = df['human_social_interaction_hours'].max()
min = df['human_social_interaction_hours'].min()
mode = df['human_social_interaction_hours'].mode()
print(f"Min:{min}\nMax:{max}\nMode:{mode[0]}")
# Out:
# Min:0.0
# Max:9.75
# Mode:3.72

# %%
# Visualization
plt.figure(figsize=(4, 8))
plt.title('BoxPlot for Human Social Interaction')
plt.ylabel('Number of Hours')
plt.boxplot(x=df['human_social_interaction_hours'], vert=True, patch_artist=True, boxprops={'facecolor': 'red', 'edgecolor': 'black'});
# Out:
# /var/folders/5x/8lgxf25n21j4dtm6mpf28s0r0000gn/T/ipykernel_10861/1601896643.py:5: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(x=df['human_social_interaction_hours'], vert=True, patch_artist=True, boxprops={'facecolor': 'red', 'edgecolor': 'black'});

# %% [markdown]
# Insights:
# - People interact with other people daily ranging from 0 - 9.75 hours
# - Most of the people interact with other people for around 4 hours per day
# - Very less people either do not interact or they interact over 8 hours

# %% [markdown]
# #### Exploring the `social_media_hours_daily` feature

# %% [markdown]
# - This feature tells us that how many number of hours does the surveyor spend on social media on a daily basis.

# %%
# Range
max = df['social_media_hours_daily'].max()
min = df['social_media_hours_daily'].min()
mode = df['social_media_hours_daily'].mode()
print(f"Min:{min}\nMax:{max}\nMode:{mode[0]}")
# Out:
# Min:0.0
# Max:6.7
# Mode:0.0

# %%
# Visualization
plt.figure(figsize=(4, 8))
plt.title('Violin Plot for Daily Social Media Hours')
plt.xlabel('')
plt.ylabel('Number of Hours')
plt.violinplot(dataset=df['social_media_hours_daily'], vert=True, showmeans=True, showextrema=True, showmedians=True)
# Out:
# /var/folders/5x/8lgxf25n21j4dtm6mpf28s0r0000gn/T/ipykernel_10861/3714760565.py:6: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.violinplot(dataset=df['social_media_hours_daily'], vert=True, showmeans=True, showextrema=True, showmedians=True)
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x11de19400>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x1280a7860>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x128215790>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1282000e0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x128225130>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x128217170>}

# %% [markdown]
# Insights:
# - Most of the people use social media for around 2.5 hours daily
# - The higher end of users use ot for more than 6 hours and the lower end of users use it for less than 1 hour daily

# %% [markdown]
# #### Exploring the `screen_time_total_hours` feature

# %% [markdown]
# - This feature tells us how many hours on average does the user spend using a screen daily.
# - This includes his time on screen on a mobile phone, laptop, tablet, television etc...

# %%
# Range
max = df['screen_time_total_hours'].max()
min = df['screen_time_total_hours'].min()
mode = df['screen_time_total_hours'].mode()
print(f"Min:{min}\nMax:{max}\nMode:{mode[0]}")
# Out:
# Min:1.0
# Max:14.3
# Mode:1.0

# %%
# Visualization
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='screen_time_total_hours', bins=15, kde=True, color='orange')
plt.title('Frequency Distribution by Daily AI Chat Hours')
plt.xlabel('Number of Hours')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - Most of the people have a screen time of around 5 hours
# - The lower end of users use the screen for less than 1 hour
# - The higher end of users use the screen for more than 12 hours daily
# - The users on the higher end of the spectrum have more possibility of getting dependent

# %% [markdown]
# #### Exploring the `number_of_close_friends` feature

# %% [markdown]
# - This feature tells us how many close friends does the user have.

# %%
# Measures of Central Tendency
mean = df['number_of_close_friends'].mean()
median = df['number_of_close_friends'].median()
mode = df['number_of_close_friends'].mode()
print(f"Mean:{mean}\nMedian:{median}\nMode:{mode[0]}")
# Out:
# Mean:4.096
# Median:4.0
# Mode:5

# %%
# Visualization
plt.title('Distribution by Number of Close Friends')
plt.xlabel('Number of Close Friends')
plt.ylabel('Number of Participants')
plt.bar(x=df['number_of_close_friends'].value_counts().index, height=df['number_of_close_friends'].value_counts().values, color='skyblue', edgecolor='black')
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# Insights:
# - Most of the popele have around 3-5 close friends
# - The more the close friends you have, the possibility of getting dependent on an AI companion becomes less

# %% [markdown]
# #### Exploring the `loneliness_score` feature

# %% [markdown]
# - This feature tells us how lonely the surveyor feels.
# - The surveyor has rated his/her lonliness on a scale of 0-10

# %%
# Measures of Central Tendency
mean = df['loneliness_score'].mean()
median = df['loneliness_score'].median()
mode = df['loneliness_score'].mode()
print(f"Mean:{mean}\nMedian:{median}\nMode:{mode[0]}")
# Out:
# Mean:5.0729
# Median:5.1
# Mode:1.0

# %%
# Visualization
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='loneliness_score', bins=10, kde=True, color='maroon')
plt.title('Frequency Distribution by Loneliness Score')
plt.xlabel('Loneliness Score')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - The graph for the loneliness score is relatively flat
# - Most of the people would rate themselves 5 on a scale of 10
# - The higher the score, the more susceptible you are to become dependent

# %% [markdown]
# #### Exploring the `emotional_attachment_score` feature

# %% [markdown]
# - This feature tells us how much is the user emotionally attached to the AI Chatbot that he/she uses.
# - The score ranges from 0 - 10

# %%
# Measures of Central Tendency
mean = df['emotional_attachment_score'].mean()
median = df['emotional_attachment_score'].median()
mode = df['emotional_attachment_score'].mode()
print(f"Mean:{mean}\nMedian:{median}\nMode:{mode[0]}")
# Out:
# Mean:4.562699999999999
# Median:4.5
# Mode:1.0

# %%
# Visualization
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='emotional_attachment_score', bins=10, kde=True, color='beige')
plt.title('Frequency Distribution by Emotional Attachment Score')
plt.xlabel('Emotional Attachment Score')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - Most of the people have given a score of 0
# - This means that most of the people are not emotionally dependent on AI
# - Very few people have crossed the 7 rating mark when it comes to emotional dependence on AI

# %% [markdown]
# #### Exploring the `real_relationship_satisfaction` feature

# %% [markdown]
# - This feature lets the surveyor rate his/her satisfaction with the relationships he/she is in.
# - This feature has a range of 0 - 10
# - Relationship encompasses relationships with friends, family, partner, colleagues etc...

# %%
# Measures of Central Tendency
mean = df['real_relationship_satisfaction'].mean()
median = df['real_relationship_satisfaction'].median()
mode = df['real_relationship_satisfaction'].mode()
print(f"Mean:{mean}\nMedian:{median}\nMode:{mode[0]}")
# Out:
# Mean:6.0004
# Median:6.05
# Mode:10.0

# %%
# Visualization
plt.figure(figsize=(15, 6))
sns.histplot(data=df, x='real_relationship_satisfaction', bins=10, kde=True, color='turquoise')
plt.title('Frequency Distribution by Relationship Satisfaction Score')
plt.xlabel('Relationship Satisfaction Score')
plt.ylabel('Number of Participants')
# Out:
# Text(0, 0.5, 'Number of Participants')

# %% [markdown]
# Insights:
# - Most of the people have scored themselves at 4-6
# - This is the midway range
# - This signals that most of the poeple think that the relationships they engage in are worthwhile and important to them, they feel complete and satisfied fulfilling them

# %% [markdown]
# #### Exploring the `prefers_ai_over_humans` feature

# %% [markdown]
# - This is a boolean feature which tells us whether the surveyor prefers AI over a real human being.
# - The context for this preference can be over facts such as trust, emotional safety etc...

# %%
# Value Counts
preference_counts = df['prefers_ai_over_humans'].value_counts()
preference_counts
# Out:
# prefers_ai_over_humans
# No     733
# Yes    267
# Name: count, dtype: int64

# %%
# Visualtization
plt.figure(figsize=(8, 8))
colors = ['#99ff99', '#c2c2f0']
plt.title('Percentage of People that prefer AI over humans')
preference_counts.plot(
    kind='pie', 
    autopct='%1.1f%%', 
    colors=colors,
    startangle=90,
    explode=(0.05, 0) 
)
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# Insights:
# - Most of the people prefer Humans over AI
